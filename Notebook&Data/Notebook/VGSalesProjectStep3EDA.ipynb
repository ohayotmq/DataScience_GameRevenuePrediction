# %% [markdown]
# # Step 3: Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("game_info_cleaned.csv")
df.head()
# Out:
#                                          Title      Genre Console  \
# 0                               Tomb Raider II  Adventure      PS
# 1  LEGO Indiana Jones: The Original Adventures  Adventure    X360
# 2    Tomb Raider III: Adventures of Lara Croft  Adventure      PS
# 3                   LEGO Batman: The Videogame  Adventure    X360
# 4                                   L.A. Noire  Adventure     PS3
#
#                   Publisher  Total Sales (m)  NA Sales (m)  EU Sales (m)  \
# 0         Eidos Interactive             5.24          2.30          2.46
# 1                 LucasArts             3.76          2.40          1.01
# 2         Eidos Interactive             3.54          1.66          1.58
# 3  Warner Bros. Interactive             3.44          2.07          1.04
# 4            Rockstar Games             3.21          1.29          1.31
#
#    JP Sales (m)  Other Sales (m)  Release Month  Release Year
# 0          0.20             0.28             10          1997
# 1          0.00             0.36              6          2008
# 2          0.12             0.18             11          1998
# 3          0.00             0.34              9          2008
# 4          0.12             0.49             11          2011

# %%
df.describe()
# Out:
#        Total Sales (m)  NA Sales (m)  EU Sales (m)  JP Sales (m)  \
# count     17517.000000  17517.000000  17517.000000  17517.000000
# mean          0.376804      0.190969      0.109314      0.039130
# std           0.832911      0.436692      0.342346      0.115766
# min           0.010000      0.000000      0.000000      0.000000
# 25%           0.050000      0.000000      0.000000      0.000000
# 50%           0.140000      0.060000      0.020000      0.000000
# 75%           0.380000      0.190000      0.080000      0.020000
# max          20.320000      9.760000      9.850000      2.130000
#
#        Other Sales (m)  Release Month  Release Year
# count     17517.000000   17517.000000  17517.000000
# mean          0.037139       7.314723   2007.650511
# std           0.118596       3.401099      6.186815
# min           0.000000       1.000000   1970.000000
# 25%           0.000000       4.000000   2004.000000
# 50%           0.010000       8.000000   2008.000000
# 75%           0.030000      10.000000   2011.000000
# max           3.120000      12.000000   2020.000000

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Console', 'Publisher', 'Total Sales (m)',
#        'NA Sales (m)', 'EU Sales (m)', 'JP Sales (m)', 'Other Sales (m)',
#        'Release Month', 'Release Year'],
#       dtype='object')

# %% [markdown]
# ### We will first use frequency tables, bar graphs, and histograms to obtain a better understanding of our data
# #### We will look at:
# #### 1) The frequency dist. of genres, consoles, publishers, release years, and titles
# #### 2) The dist. through a histogram of the Total Sales, NA Sales, EU Sales, JP Sales, amd Other Sales

# %% [markdown]
# ## Frequency Dist. of Genres

# %%
pd.crosstab(index=df['Genre'], columns='count').sort_values('count', ascending=False)
# Out:
# col_0             count
# Genre
# Action             2678
# Sports             2475
# Misc               1826
# Adventure          1681
# Role-Playing       1408
# Shooter            1376
# Racing             1343
# Simulation         1000
# Platform            903
# Fighting            852
# Strategy            691
# Puzzle              626
# Action-Adventure    257
# Visual Novel        197
# Music               138
# MMO                  30
# Party                28
# Education             4
# Board Game            3
# Sandbox               1

# %% [markdown]
# ## Frequency Dist. of Consoles

# %%
pd.crosstab(index=df['Console'], columns='count').sort_values('count', ascending=False)
# Out:
# col_0    count
# Console
# DS        2140
# PS2       2091
# PS3       1305
# Wii       1275
# X360      1256
# PSP       1252
# PS        1125
# PC         938
# PS4        891
# XB         822
# GBA        819
# PSV        636
# 3DS        542
# GC         525
# XOne       517
# N64        277
# NS         246
# SNES       196
# SAT        175
# WiiU       139
# 2600       126
# DC          49
# NES         47
# GB          46
# GEN         27
# NG          12
# PSN          9
# WS           7
# XBL          5
# SCD          5
# 3DO          4
# GBC          3
# VC           3
# PCE          2
# WW           1
# GG           1
# Mob          1
# OSX          1
# PCFX         1

# %% [markdown]
# ## Frequency Dist. of Release Years

# %%
pd.crosstab(index=df['Release Year'], columns='count')
# Out:
# col_0         count
# Release Year
# 1970              9
# 1977              3
# 1978              7
# 1979              1
# 1980              5
# 1981              6
# 1982             44
# 1983             37
# 1984             10
# 1985              4
# 1986             11
# 1987              7
# 1988             11
# 1989              7
# 1990              7
# 1991             20
# 1992             23
# 1993             43
# 1994             94
# 1995            173
# 1996            267
# 1997            233
# 1998            299
# 1999            322
# 2000            376
# 2001            460
# 2002            786
# 2003            766
# 2004            726
# 2005            911
# 2006            937
# 2007           1159
# 2008           1453
# 2009           1533
# 2010           1307
# 2011           1188
# 2012            651
# 2013            494
# 2014            584
# 2015            598
# 2016            600
# 2017            663
# 2018            626
# 2019             34
# 2020             22

# %% [markdown]
# ## Frequency Dist. of Publishers

# %%
pd.crosstab(index=df['Publisher'], columns='count').sort_values('count', ascending=False)
# Out:
# col_0            count
# Publisher
# Activision        1017
# Ubisoft            926
# Electronic Arts    803
# Konami             746
# THQ                701
# ...                ...
# Imageworks           1
# Nippon Amuse         1
# Imax                 1
# Evolution Games      1
# Digiturbo            1
#
# [673 rows x 1 columns]

# %% [markdown]
# ## Histogram of Total Sales

# %%
sns.set_style("white")
plt.figure(figsize = (8,6))
plt.hist(df["Total Sales (m)"],
        bins = 14,
        color = "#108a99")
plt.title("Distribution of Total Sales", fontsize = 14, weight = "bold")
plt.xlabel("Total Sales (m)")
plt.ylabel("Number of Titles")
sns.despine()
#plt.savefig("TotalSalesHistogram.png")
plt.show()

# %% [markdown]
# ## Histogram of NA sales

# %%
sns.set_style("white")
plt.figure(figsize = (8,6))
plt.hist(df["NA Sales (m)"],
        bins = 14,
        color = "#108a99")
plt.title("Distribution of NA Sales", fontsize = 14, weight = "bold")
plt.xlabel("NA Sales (m)")
plt.ylabel("Number of Titles")
sns.despine()
#plt.savefig("NASalesHistogram.png")
plt.show()

# %% [markdown]
# ## Histogram of EU Sales

# %%
sns.set_style("white")
plt.figure(figsize = (8,6))
plt.hist(df["EU Sales (m)"],
        bins = 14,
        color = "#108a99")
plt.title("Distribution of EU Sales", fontsize = 14, weight = "bold")
plt.xlabel("EU Sales (m)")
plt.ylabel("Number of Titles")
sns.despine()
#plt.savefig("EUSalesHistogram.png")
plt.show()

# %% [markdown]
# ## Histogram of JP Sales

# %%
sns.set_style("white")
plt.figure(figsize = (8,6))
plt.hist(df["JP Sales (m)"],
        bins = 14,
        color = "#108a99")
plt.title("Distribution of JP Sales", fontsize = 14, weight = "bold")
plt.xlabel("JP Sales (m)")
plt.ylabel("Number of Titles")
sns.despine()
#plt.savefig("JPSalesHistogram.png")
plt.show()

# %% [markdown]
# ## Histogram of Other Sales

# %%
sns.set_style("white")
plt.figure(figsize = (8,6))
plt.hist(df["Other Sales (m)"],
        bins = 14,
        color = "#108a99")
plt.title("Distribution of Other Sales", fontsize = 14, weight = "bold")
plt.xlabel("Other Sales (m)")
plt.ylabel("Number of Titles")
sns.despine()
#plt.savefig("OtherSalesHistogram.png")
plt.show()

# %% [markdown]
# ## Relationship of Qualitative Columns through Heatmap

# %% [markdown]
# ### We will next explore further and attempt to gain insight from our data
# #### We will look at:<br />1) Total Sales by Genre, Total Sales by Console, Total Sales by top 20 Publishers<br />2) Best Selling Games worldwide and per country grouping<br />3)Total Sales from each country grouping over time<br />4)Total Sales by Genre, Console, and Publisher brokedn up by country grouping

# %% [markdown]
# ## Total Sales(m) by Genre

# %%
gen_df = df.groupby(['Genre'], as_index=False)['Total Sales (m)'].sum().sort_values('Total Sales (m)', ascending=False)
gen_df = gen_df.reset_index(drop=True)
gen_df
# Out:
#                Genre  Total Sales (m)
# 0             Sports          1186.78
# 1             Action          1125.16
# 2            Shooter           995.48
# 3               Misc           557.59
# 4             Racing           523.52
# 5       Role-Playing           426.51
# 6           Platform           349.15
# 7           Fighting           340.39
# 8          Adventure           325.33
# 9         Simulation           300.48
# 10  Action-Adventure           148.52
# 11            Puzzle           127.06
# 12          Strategy           118.27
# 13             Music            51.75
# 14               MMO             9.31
# 15             Party             6.21
# 16      Visual Novel             5.78
# 17           Sandbox             1.89
# 18         Education             0.97
# 19        Board Game             0.33

# %%
my_colors = ('#173F5F', '#20639B', '#3CAEA3', '#F6D55C', '#ED553B')
plt.figure(figsize =(12,9))
plt.bar(x = gen_df['Genre'], 
        height = gen_df["Total Sales (m)"],
        color = my_colors,
        edgecolor = 'black')
plt.xticks(rotation = 85, fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Total Sales(m) by Genre", fontsize = 16, fontweight = "bold")
plt.ylabel("Total Sales(m)", fontsize = 13)
#plt.savefig("TotalSalesByGenre.png")
plt.show()

# %% [markdown]
# ## Total Sales(m) by Console

# %%
con_df = df.groupby(['Console'], as_index=False)['Total Sales (m)'].sum().sort_values('Total Sales (m)', ascending=False)
con_df = con_df.reset_index(drop=True)
con_df
# Out:
#    Console  Total Sales (m)
# 0      PS2          1025.38
# 1     X360           859.41
# 2      PS3           839.05
# 3       PS           546.21
# 4      PS4           539.92
# 5      Wii           458.92
# 6       DS           457.77
# 7     XOne           268.96
# 8      PSP           245.19
# 9       XB           232.05
# 10     GBA           224.42
# 11      PC           168.96
# 12      GC           119.29
# 13     3DS            99.24
# 14     N64            93.26
# 15    2600            75.66
# 16    SNES            65.71
# 17     PSV            62.98
# 18     NES            47.93
# 19      NS            36.43
# 20    WiiU            35.42
# 21     SAT            33.67
# 22      GB            19.84
# 23     GEN            18.83
# 24      DC            13.31
# 25     GBC             4.34
# 26     PSN             3.81
# 27      NG             1.44
# 28      WS             1.43
# 29     SCD             0.37
# 30      VC             0.35
# 31      WW             0.25
# 32     XBL             0.20
# 33     3DO             0.19
# 34     PCE             0.16
# 35      GG             0.04
# 36     OSX             0.03
# 37     Mob             0.03
# 38    PCFX             0.03

# %%
my_colors = ('#173F5F', '#20639B', '#3CAEA3', '#F6D55C', '#ED553B')
plt.figure(figsize =(12,9))
plt.bar(x = con_df["Console"], 
        height = con_df["Total Sales (m)"],
        color = my_colors,
        edgecolor = 'Black')
plt.xticks(rotation = 85, fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Total Sales(m) by Console", fontsize = 16, fontweight = "bold")
plt.ylabel("Total Sales(m)", fontsize = 13)
#plt.savefig("TotalSalesByConsole.png")
plt.show()

# %% [markdown]
# ## Total Sales(m) by Publisher
# #### Since their are hundreds of publishers in our data frame, we will first group our data by 'Publisher' and then sum the Total Sales respectively. Then we will isolate the top 20 publishers that made the most in sales
# #### This we dont have a bar graph with hundreds of values in the x axis

# %%
pub_df = df.groupby(['Publisher'], as_index=False)['Total Sales (m)'].sum().sort_values('Total Sales (m)', ascending=False)[:20]
pub_df = pub_df.reset_index(drop=True)
pub_df
# Out:
#                                  Publisher  Total Sales (m)
# 0                               Activision           722.77
# 1                          Electronic Arts           644.13
# 2                                EA Sports           485.66
# 3                                  Ubisoft           462.57
# 4                                      THQ           320.89
# 5              Sony Computer Entertainment           311.08
# 6                           Rockstar Games           239.67
# 7                                   Konami           210.70
# 8                                     Sega           206.38
# 9                                 Nintendo           140.80
# 10                                  Capcom           131.24
# 11                               LucasArts           118.48
# 12                      Bethesda Softworks           111.08
# 13  Warner Bros. Interactive Entertainment           103.51
# 14              Disney Interactive Studios           103.30
# 15                                   Atari           101.63
# 16                               2K Sports           101.04
# 17                             Square Enix            95.74
# 18                                   Namco            91.03
# 19                            Midway Games            87.57

# %%
my_colors = ('#173F5F', '#20639B', '#3CAEA3', '#F6D55C', '#ED553B')
plt.figure(figsize =(12,9))
plt.bar(x =  pub_df['Publisher'], 
        height = pub_df["Total Sales (m)"],
        color = my_colors,
        edgecolor = 'black')
plt.xticks(rotation = 85, fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Total Sales by Publisher (Top 20) ", fontsize = 16, fontweight = "bold")
plt.ylabel("Total Sales(m)", fontsize = 13)
#plt.savefig("TotalSalesByPublisher20.png")
plt.show()

# %% [markdown]
# ## Best Selling Games Worldwide

# %%
bsgw_df = df.groupby(['Title'], as_index=False)['Total Sales (m)'].sum().sort_values('Total Sales (m)', ascending=False)[:10]
bsgw_df = bsgw_df.reset_index(drop=True).sort_values('Total Sales (m)', ascending=True)
bsgw_df
# Out:
#                             Title  Total Sales (m)
# 9  Call of Duty: Advanced Warfare            21.78
# 8             Grand Theft Auto IV            22.53
# 7                       Minecraft            24.01
# 6  Call of Duty: Modern Warfare 2            25.02
# 5       Call of Duty: Black Ops 3            26.72
# 4            Call of Duty: Ghosts            28.80
# 3      Call of Duty: Black Ops II            29.59
# 2  Call of Duty: Modern Warfare 3            30.71
# 1         Call of Duty: Black Ops            30.99
# 0              Grand Theft Auto V            64.29

# %%
my_colors = ('#173F5F', '#20639B', '#3CAEA3', '#F6D55C', '#ED553B')
plt.figure(figsize =(12,9))
plt.barh(y =  bsgw_df['Title'], 
        width = bsgw_df["Total Sales (m)"],
        color = my_colors,
        edgecolor = 'black')
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Top 10 Best Selling Games Worldwide", fontsize = 16, fontweight = "bold")
plt.xlabel("Total Sales(m)", fontsize = 13)
#plt.savefig("Top10BestSellingGames.png")
plt.show()

# %% [markdown]
# ## Best Selling Games per Country Grouping

# %%
bsgna_df = df.groupby(['Title'], as_index=False)['NA Sales (m)'].sum().sort_values('NA Sales (m)', ascending=False)[:10]
bsgna_df = bsgna_df.reset_index(drop=True).sort_values('NA Sales (m)', ascending=True)
bsgna_df
# Out:
#                               Title  NA Sales (m)
# 9    Call of Duty: Advanced Warfare         10.66
# 8  Guitar Hero III: Legends of Rock         11.14
# 7               Grand Theft Auto IV         11.60
# 6         Call of Duty: Black Ops 3         12.82
# 5    Call of Duty: Modern Warfare 2         13.54
# 4        Call of Duty: Black Ops II         14.12
# 3              Call of Duty: Ghosts         15.06
# 2    Call of Duty: Modern Warfare 3         15.57
# 1           Call of Duty: Black Ops         17.65
# 0                Grand Theft Auto V         26.19

# %%
my_colors = ('#173F5F', '#20639B', '#3CAEA3', '#F6D55C', '#ED553B')
plt.figure(figsize =(12,9))
plt.barh(y =  bsgna_df['Title'], 
        width = bsgna_df["NA Sales (m)"],
        color = my_colors,
        edgecolor = 'black')
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Top 10 Best Selling Games NA", fontsize = 16, fontweight = "bold")
plt.xlabel("NA Sales(m)", fontsize = 13)
#plt.savefig("Top10BestSellingGamesNA.png")
plt.show()

# %%
bsgeu_df = df.groupby(['Title'], as_index=False)['EU Sales (m)'].sum().sort_values('EU Sales (m)', ascending=False)[:10]
bsgeu_df = bsgeu_df.reset_index(drop=True).sort_values('EU Sales (m)', ascending=True)
bsgeu_df
# Out:
#                             Title  EU Sales (m)
# 9       Call of Duty: Black Ops 3          9.76
# 8                         FIFA 13         10.11
# 7                         FIFA 16         10.56
# 6      Call of Duty: Black Ops II         11.08
# 5  Call of Duty: Modern Warfare 3         11.26
# 4                         FIFA 18         11.78
# 3                         FIFA 17         12.07
# 2                         FIFA 14         12.14
# 1                         FIFA 15         12.45
# 0              Grand Theft Auto V         28.14

# %%
my_colors = ('#173F5F', '#20639B', '#3CAEA3', '#F6D55C', '#ED553B')
plt.figure(figsize =(12,9))
plt.barh(y =  bsgeu_df['Title'], 
        width = bsgeu_df["EU Sales (m)"],
        color = my_colors,
        edgecolor = 'black')
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Top 10 Best Selling Games EU", fontsize = 16, fontweight = "bold")
plt.xlabel("EU Sales(m)", fontsize = 13)
#plt.savefig("Top10BestSellingGamesEU.png")
plt.show()

# %%
bsgjp_df = df.groupby(['Title'], as_index=False)['JP Sales (m)'].sum().sort_values('JP Sales (m)', ascending=False)[:10]
bsgjp_df = bsgjp_df.reset_index(drop=True).sort_values('JP Sales (m)', ascending=True)
bsgjp_df
# Out:
#                                                Title  JP Sales (m)
# 9  Ninja Hattori Kun: Ninja wa Shuugyou Degogiru ...          1.50
# 8                                 Grand Theft Auto V          1.66
# 6                                    Super Puyo Puyo          1.69
# 7                     Tomodachi Collection: New Life          1.69
# 5                                    Dragon Quest XI          1.82
# 4                                 Final Fantasy XIII          1.88
# 2                                    R.B.I. Baseball          2.05
# 3                        Famista '89 - Kaimaku Han!!          2.05
# 1                                          Minecraft          2.50
# 0                                     Hot Shots Golf          4.26

# %%
my_colors = ('#173F5F', '#20639B', '#3CAEA3', '#F6D55C', '#ED553B')
plt.figure(figsize =(12,9))
plt.barh(y =  bsgjp_df['Title'], 
        width = bsgjp_df["JP Sales (m)"],
        color = my_colors,
        edgecolor = 'black')
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Top 10 Best Selling Games JP", fontsize = 16, fontweight = "bold")
plt.xlabel("JP Sales(m)", fontsize = 13)
#plt.savefig("Top10BestSellingGamesJP.png")
plt.show()

# %%
bsgot_df = df.groupby(['Title'], as_index=False)['Other Sales (m)'].sum().sort_values('Other Sales (m)', ascending=False)[:10]
bsgot_df = bsgot_df.reset_index(drop=True).sort_values('Other Sales (m)', ascending=True)
bsgot_df
# Out:
#                             Title  Other Sales (m)
# 9  Call of Duty: Modern Warfare 2             2.95
# 8                       Minecraft             2.96
# 7  Call of Duty: Modern Warfare 3             3.26
# 6         Call of Duty: Black Ops             3.31
# 5       Pro Evolution Soccer 2008             3.51
# 4                  FIFA Soccer 08             3.53
# 3       Call of Duty: Black Ops 3             3.63
# 2            Call of Duty: Ghosts             3.65
# 1      Call of Duty: Black Ops II             3.67
# 0              Grand Theft Auto V             8.32

# %%
my_colors = ('#173F5F', '#20639B', '#3CAEA3', '#F6D55C', '#ED553B')
plt.figure(figsize =(12,9))
plt.barh(y =  bsgot_df['Title'], 
        width = bsgot_df["Other Sales (m)"],
        color = my_colors,
        edgecolor = 'black')
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Top 10 Best Selling Games Other", fontsize = 16, fontweight = "bold")
plt.xlabel("Other Sales(m)", fontsize = 13)
#plt.savefig("Top10BestSellingGamesOther.png")
plt.show()

# %% [markdown]
# ## Total Sales from each country grouping over time

# %%
import numpy as np
yearly_sales_df = df.groupby(['Release Year'], as_index=False).agg({'Total Sales (m)': np.sum,
                                                                    'NA Sales (m)': np.sum,
                                                                    'EU Sales (m)': np.sum,
                                                                    'JP Sales (m)': np.sum,
                                                                    'Other Sales (m)': np.sum})

#Dropped the year 1970 as there is a tremendous gap between 70-78 with no data
yearly_sales_df = yearly_sales_df.drop([0,1])

yearly_sales_df = yearly_sales_df.reset_index(drop=True)
yearly_sales_df
# Out:
# C:\Users\vjpon\AppData\Local\Temp\ipykernel_18568\4228689036.py:2: FutureWarning: The provided callable <function sum at 0x000002943CE745E0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   yearly_sales_df = df.groupby(['Release Year'], as_index=False).agg({'Total Sales (m)': np.sum,
#     Release Year  Total Sales (m)  NA Sales (m)  EU Sales (m)  JP Sales (m)  \
# 0           1978             2.36          2.20          0.14          0.00
# 1           1979             0.31          0.29          0.02          0.00
# 2           1980             2.26          2.11          0.13          0.00
# 3           1981             7.73          7.21          0.45          0.00
# 4           1982            28.99         27.06          1.60          0.00
# 5           1983            22.68         21.15          1.29          0.00
# 6           1984             4.85          3.89          0.24          0.69
# 7           1985             2.19          0.84          0.13          1.20
# 8           1986            10.35          1.66          0.36          8.31
# 9           1987             5.59          2.11          0.21          3.24
# 10          1988             8.73          2.39          0.19          6.10
# 11          1989             9.12          4.29          0.47          4.31
# 12          1990             9.07          4.44          0.94          3.56
# 13          1991             6.05          0.42          0.05          5.57
# 14          1992             9.38          2.11          0.36          6.77
# 15          1993            20.16          6.40          2.08         11.37
# 16          1994            36.85         11.46          4.25         20.45
# 17          1995            52.98         15.19          7.76         28.49
# 18          1996           101.36         39.61         21.71         35.79
# 19          1997           105.89         48.75         23.86         28.78
# 20          1998           132.23         70.80         30.36         25.16
# 21          1999           169.61         88.56         47.78         24.95
# 22          2000           171.12         83.35         51.27         26.65
# 23          2001           226.75        121.72         67.83         20.11
# 24          2002           314.50        176.84         90.33         23.53
# 25          2003           300.89        165.58         90.99         20.54
# 26          2004           284.68        165.02         80.57         16.99
# 27          2005           313.48        193.39         74.53         17.32
# 28          2006           244.42        140.67         51.41         26.72
# 29          2007           436.39        237.23        109.52         30.93
# 30          2008           538.11        290.08        146.42         29.95
# 31          2009           495.36        263.43        140.83         30.62
# 32          2010           454.02        239.69        133.05         34.13
# 33          2011           440.32        213.47        143.44         35.92
# 34          2012           285.47        125.56         96.74         31.70
# 35          2013           266.00        116.72         95.70         23.07
# 36          2014           292.11        118.76        114.66         23.75
# 37          2015           230.45         98.37         82.76         20.78
# 38          2016           208.02         81.54         79.14         22.37
# 39          2017           191.96         78.63         71.10         18.89
# 40          2018           148.03         68.91         49.42         11.29
# 41          2019             2.55          0.00          0.08          2.46
# 42          2020             3.45          0.52          0.33          2.53
#
#     Other Sales (m)
# 0              0.00
# 1              0.00
# 2              0.02
# 3              0.08
# 4              0.26
# 5              0.24
# 6              0.04
# 7              0.02
# 8              0.02
# 9              0.03
# 10             0.02
# 11             0.05
# 12             0.13
# 13             0.01
# 14             0.14
# 15             0.31
# 16             0.68
# 17             1.57
# 18             4.26
# 19             4.51
# 20             5.83
# 21             8.15
# 22             9.91
# 23            17.15
# 24            23.24
# 25            23.44
# 26            21.70
# 27            27.86
# 28            24.91
# 29            58.24
# 30            71.59
# 31            60.41
# 32            46.54
# 33            47.50
# 34            31.35
# 35            30.51
# 36            34.89
# 37            28.42
# 38            25.06
# 39            23.20
# 40            18.10
# 41             0.01
# 42             0.09

# %%
labels = ["Total", "NA", "EU", "JP", "Other"]
plt.figure(figsize = (20,14))
plt.plot(yearly_sales_df["Release Year"], yearly_sales_df["Total Sales (m)"], color = "#173F5F")
plt.plot(yearly_sales_df["Release Year"], yearly_sales_df["NA Sales (m)"], color = "#20639B")
plt.plot(yearly_sales_df["Release Year"], yearly_sales_df["EU Sales (m)"], color = "#3CAEA3")
plt.plot(yearly_sales_df["Release Year"], yearly_sales_df["JP Sales (m)"], color = "#F6D55C")
plt.plot(yearly_sales_df["Release Year"], yearly_sales_df["Other Sales (m)"], color = "#ED553B")
plt.title("Sales over Time (1978-2020)", fontsize = 16, fontweight = "bold")
plt.ylabel("Sales (m)", fontsize = 15)
plt.yticks(fontsize = 13)
plt.xlabel("Release Year", fontsize = 15)
plt.xticks(yearly_sales_df["Release Year"], rotation = 45, fontsize = 13)
plt.legend(labels = labels, fontsize = "large")
#plt.savefig("TotalSalesOverTime.png")
plt.show()

# %% [markdown]
# ## Total Sales by Genre broken up by country grouping

# %%
genre_cgsales_df = df.groupby(['Genre'], as_index=False).agg({'Total Sales (m)': np.sum,
                                                                    'NA Sales (m)': np.sum,
                                                                    'EU Sales (m)': np.sum,
                                                                    'JP Sales (m)': np.sum,
                                                                    'Other Sales (m)': np.sum})

genre_cgsales_df = genre_cgsales_df.sort_values('Total Sales (m)', ascending=False)
genre_cgsales_df = genre_cgsales_df.reset_index(drop=True)
genre_cgsales_df
# Out:
# C:\Users\vjpon\AppData\Local\Temp\ipykernel_18568\1104629996.py:1: FutureWarning: The provided callable <function sum at 0x000002943CE745E0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   genre_cgsales_df = df.groupby(['Genre'], as_index=False).agg({'Total Sales (m)': np.sum,
# C:\Users\vjpon\AppData\Local\Temp\ipykernel_18568\1104629996.py:1: FutureWarning: The provided callable <function sum at 0x000002943CE745E0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   genre_cgsales_df = df.groupby(['Genre'], as_index=False).agg({'Total Sales (m)': np.sum,
#                Genre  Total Sales (m)  NA Sales (m)  EU Sales (m)  \
# 0             Sports          1186.78        607.45        341.60
# 1             Action          1125.16        589.53        342.47
# 2            Shooter           995.48        528.27        324.74
# 3               Misc           557.59        295.65        146.63
# 4             Racing           523.52        269.72        177.77
# 5       Role-Playing           426.51        171.67         91.02
# 6           Platform           349.15        187.96         99.39
# 7           Fighting           340.39        173.86         79.76
# 8          Adventure           325.33        157.26         91.50
# 9         Simulation           300.48        152.82         86.86
# 10  Action-Adventure           148.52         65.09         59.52
# 11            Puzzle           127.06         64.36         25.76
# 12          Strategy           118.27         47.06         27.01
# 13             Music            51.75         25.97         15.02
# 14               MMO             9.31          3.95          2.94
# 15             Party             6.21          2.67          1.81
# 16      Visual Novel             5.78          0.49          0.07
# 17           Sandbox             1.89          0.69          0.56
# 18         Education             0.97          0.68          0.20
# 19        Board Game             0.33          0.06          0.22
#
#     JP Sales (m)  Other Sales (m)
# 0         109.00           128.10
# 1          79.79           112.40
# 2          33.97           108.43
# 3          56.16            58.52
# 4          19.76            56.06
# 5         130.27            33.75
# 6          31.08            30.38
# 7          58.12            28.58
# 8          46.07            30.11
# 9          35.84            24.34
# 10          5.46            18.40
# 11         29.08             7.38
# 12         36.80             7.28
# 13          5.84             4.93
# 14          1.39             1.03
# 15          1.19             0.52
# 16          5.06             0.13
# 17          0.52             0.12
# 18          0.00             0.08
# 19          0.04             0.02

# %%
#my_colors = ('#173F5F', '#20639B', '#3CAEA3', '#F6D55C', '#ED553B')
labels = ["NA", "EU", "JP", "Other"]
plt.figure(figsize =(12,9))

bars1 = np.add(genre_cgsales_df["NA Sales (m)"], genre_cgsales_df["EU Sales (m)"]).tolist()
bars2 = np.add(genre_cgsales_df["JP Sales (m)"], bars1).tolist()

p1 = plt.bar(x = genre_cgsales_df['Genre'], 
        height = genre_cgsales_df["NA Sales (m)"],
        color = '#ED553B',
        edgecolor = 'black')

p2 = plt.bar(x = genre_cgsales_df['Genre'],
        bottom = genre_cgsales_df["NA Sales (m)"],
        height = genre_cgsales_df["EU Sales (m)"],
        color = '#F6D55C',
        edgecolor = 'black')

p3 = plt.bar(x =genre_cgsales_df['Genre'], 
        bottom = bars1,
        height = genre_cgsales_df["JP Sales (m)"],
        color = '#3CAEA3',
        edgecolor = 'black')

p4 = plt.bar(x =genre_cgsales_df['Genre'],
        bottom = bars2,
        height = genre_cgsales_df["Other Sales (m)"],
        color = '#20639B',
        edgecolor = 'black')

plt.xticks(rotation = 85, fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Total Sales by Genre by Country Grouping ", fontsize = 16, fontweight = "bold")
plt.ylabel("Total Sales(m)", fontsize = 13)
plt.legend(labels = labels, fontsize = "large")
#plt.savefig("TotalSalesByGenreByCG.png")
plt.show()

# %% [markdown]
# ## Total Sales by Console broken up by country grouping

# %%
console_cgsales_df = df.groupby(['Console'], as_index=False).agg({'Total Sales (m)': np.sum,
                                                                    'NA Sales (m)': np.sum,
                                                                    'EU Sales (m)': np.sum,
                                                                    'JP Sales (m)': np.sum,
                                                                    'Other Sales (m)': np.sum})

console_cgsales_df = console_cgsales_df.sort_values('Total Sales (m)', ascending=False)
console_cgsales_df = console_cgsales_df.reset_index(drop=True)
console_cgsales_df
# Out:
# C:\Users\vjpon\AppData\Local\Temp\ipykernel_18568\3667955519.py:1: FutureWarning: The provided callable <function sum at 0x000002943CE745E0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   console_cgsales_df = df.groupby(['Console'], as_index=False).agg({'Total Sales (m)': np.sum,
# C:\Users\vjpon\AppData\Local\Temp\ipykernel_18568\3667955519.py:1: FutureWarning: The provided callable <function sum at 0x000002943CE745E0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   console_cgsales_df = df.groupby(['Console'], as_index=False).agg({'Total Sales (m)': np.sum,
#    Console  Total Sales (m)  NA Sales (m)  EU Sales (m)  JP Sales (m)  \
# 0      PS2          1025.38        489.86        295.19         86.88
# 1     X360           859.41        528.40        244.24         10.09
# 2      PS3           839.05        351.10        301.84         67.51
# 3       PS           546.21        263.26        163.73         88.28
# 4      PS4           539.92        192.18        233.40         30.69
# 5      Wii           458.92        285.25        117.64         16.60
# 6       DS           457.77        264.81         94.29         63.90
# 7     XOne           268.96        164.53         79.44          0.38
# 8      PSP           245.19         96.55         59.77         52.22
# 9       XB           232.05        166.88         55.62          0.83
# 10     GBA           224.42        140.41         54.86         23.88
# 11      PC           168.96         58.61         96.00          0.00
# 12      GC           119.29         86.31         23.77          5.85
# 13     3DS            99.24         30.37         22.24         41.71
# 14     N64            93.26         66.36         16.67          7.98
# 15    2600            75.66         70.62          4.25          0.00
# 16    SNES            65.71          6.84          1.46         57.14
# 17     PSV            62.98         13.04         15.18         26.91
# 18     NES            47.93         13.37          2.24         31.96
# 19      NS            36.43         17.71         11.63          4.23
# 20    WiiU            35.42         16.44         12.39          3.84
# 21     SAT            33.67          0.72          0.54         32.34
# 22      GB            19.84          1.84          1.00         16.87
# 23     GEN            18.83         12.55          3.64          2.05
# 24      DC            13.31          4.50          1.22          7.37
# 25     GBC             4.34          1.79          1.05          1.38
# 26     PSN             3.81          0.76          1.19          0.60
# 27      NG             1.44          0.00          0.00          1.44
# 28      WS             1.43          0.00          0.00          1.43
# 29     SCD             0.37          0.00          0.00          0.36
# 30      VC             0.35          0.00          0.29          0.05
# 31      WW             0.25          0.00          0.00          0.25
# 32     XBL             0.20          0.12          0.05          0.00
# 33     3DO             0.19          0.00          0.00          0.19
# 34     PCE             0.16          0.00          0.00          0.16
# 35      GG             0.04          0.00          0.00          0.04
# 36     OSX             0.03          0.03          0.00          0.00
# 37     Mob             0.03          0.00          0.02          0.00
# 38    PCFX             0.03          0.00          0.00          0.03
#
#     Other Sales (m)
# 0            153.58
# 1             76.72
# 2            118.83
# 3             31.10
# 4             83.55
# 5             38.84
# 6             33.88
# 7             24.53
# 8             36.59
# 9              8.17
# 10             4.47
# 11            13.51
# 12             2.90
# 13             4.88
# 14             2.03
# 15             0.69
# 16             0.26
# 17             7.81
# 18             0.36
# 19             2.75
# 20             2.73
# 21             0.07
# 22             0.14
# 23             0.61
# 24             0.20
# 25             0.12
# 26             1.22
# 27             0.00
# 28             0.00
# 29             0.00
# 30             0.01
# 31             0.00
# 32             0.01
# 33             0.00
# 34             0.00
# 35             0.00
# 36             0.00
# 37             0.00
# 38             0.00

# %%
#my_colors = ('#173F5F', '#20639B', '#3CAEA3', '#F6D55C', '#ED553B')
labels = ["NA", "EU", "JP", "Other"]
plt.figure(figsize =(12,9))

bars1 = np.add(console_cgsales_df["NA Sales (m)"], console_cgsales_df["EU Sales (m)"]).tolist()
bars2 = np.add(console_cgsales_df["JP Sales (m)"], bars1).tolist()

p1 = plt.bar(x = console_cgsales_df['Console'], 
        height = console_cgsales_df["NA Sales (m)"],
        color = '#ED553B',
        edgecolor = 'black')

p2 = plt.bar(x = console_cgsales_df['Console'],
        bottom = console_cgsales_df["NA Sales (m)"],
        height = console_cgsales_df["EU Sales (m)"],
        color = '#F6D55C',
        edgecolor = 'black')

p3 = plt.bar(x = console_cgsales_df['Console'], 
        bottom = bars1,
        height = console_cgsales_df["JP Sales (m)"],
        color = '#3CAEA3',
        edgecolor = 'black')

p4 = plt.bar(x = console_cgsales_df['Console'],
        bottom = bars2,
        height = console_cgsales_df["Other Sales (m)"],
        color = '#20639B',
        edgecolor = 'black')

plt.xticks(rotation = 85, fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Total Sales by Console by Country Grouping ", fontsize = 16, fontweight = "bold")
plt.ylabel("Total Sales(m)", fontsize = 13)
plt.legend(labels = labels, fontsize = "large")
#plt.savefig("TotalSalesByConsoleByCG.png")
plt.show()

# %% [markdown]
# ## Total Sales by Publisher broken up by country grouping

# %%
publisher_cgsales_df = df.groupby(['Publisher'], as_index=False).agg({'Total Sales (m)': np.sum,
                                                                    'NA Sales (m)': np.sum,
                                                                    'EU Sales (m)': np.sum,
                                                                    'JP Sales (m)': np.sum,
                                                                    'Other Sales (m)': np.sum})

publisher_cgsales_df = publisher_cgsales_df.sort_values('Total Sales (m)', ascending=False)[:20]
publisher_cgsales_df = publisher_cgsales_df.reset_index(drop=True)
publisher_cgsales_df
# Out:
# C:\Users\vjpon\AppData\Local\Temp\ipykernel_18568\3462053076.py:1: FutureWarning: The provided callable <function sum at 0x000002943CE745E0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   publisher_cgsales_df = df.groupby(['Publisher'], as_index=False).agg({'Total Sales (m)': np.sum,
# C:\Users\vjpon\AppData\Local\Temp\ipykernel_18568\3462053076.py:1: FutureWarning: The provided callable <function sum at 0x000002943CE745E0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   publisher_cgsales_df = df.groupby(['Publisher'], as_index=False).agg({'Total Sales (m)': np.sum,
#                                  Publisher  Total Sales (m)  NA Sales (m)  \
# 0                               Activision           722.77        423.73
# 1                          Electronic Arts           644.13        321.88
# 2                                EA Sports           485.66        267.19
# 3                                  Ubisoft           462.57        239.30
# 4                                      THQ           320.89        199.22
# 5              Sony Computer Entertainment           311.08        134.49
# 6                           Rockstar Games           239.67        114.69
# 7                                   Konami           210.70         66.18
# 8                                     Sega           206.38         84.28
# 9                                 Nintendo           140.80         53.48
# 10                                  Capcom           131.24         53.65
# 11                               LucasArts           118.48         70.56
# 12                      Bethesda Softworks           111.08         53.55
# 13  Warner Bros. Interactive Entertainment           103.51         49.47
# 14              Disney Interactive Studios           103.30         59.87
# 15                                   Atari           101.63         72.50
# 16                               2K Sports           101.04         72.32
# 17                             Square Enix            95.74         32.22
# 18                                   Namco            91.03         41.22
# 19                            Midway Games            87.57         57.46
#
#     EU Sales (m)  JP Sales (m)  Other Sales (m)
# 0         213.81          7.51            77.59
# 1         238.24          8.63            75.14
# 2         157.58          3.28            57.50
# 3         166.45          6.18            50.29
# 4          88.46          2.71            30.44
# 5          95.39         38.71            42.48
# 6          89.87          4.67            30.37
# 7          50.18         71.97            22.35
# 8          60.55         42.66            18.74
# 9          22.79         59.39             5.02
# 10         27.63         39.72            10.01
# 11         34.91          0.22            12.90
# 12         41.89          2.08            13.54
# 13         40.35          0.97            12.73
# 14         30.59          0.45            12.36
# 15         21.39          2.01             5.57
# 16         16.09          0.73            11.87
# 17         28.42         25.66             9.48
# 18         20.16         24.94             4.68
# 19         23.22          0.12             6.65

# %%
#my_colors = ('#173F5F', '#20639B', '#3CAEA3', '#F6D55C', '#ED553B')
labels = ["NA", "EU", "JP", "Other"]
plt.figure(figsize =(12,9))

bars1 = np.add(publisher_cgsales_df["NA Sales (m)"], publisher_cgsales_df["EU Sales (m)"]).tolist()
bars2 = np.add(publisher_cgsales_df["JP Sales (m)"], bars1).tolist()

p1 = plt.bar(x = publisher_cgsales_df['Publisher'], 
        height = publisher_cgsales_df["NA Sales (m)"],
        color = '#ED553B',
        edgecolor = 'black')

p2 = plt.bar(x = publisher_cgsales_df['Publisher'],
        bottom = publisher_cgsales_df["NA Sales (m)"],
        height = publisher_cgsales_df["EU Sales (m)"],
        color = '#F6D55C',
        edgecolor = 'black')

p3 = plt.bar(x = publisher_cgsales_df['Publisher'], 
        bottom = bars1,
        height = publisher_cgsales_df["JP Sales (m)"],
        color = '#3CAEA3',
        edgecolor = 'black')

p4 = plt.bar(x = publisher_cgsales_df['Publisher'],
        bottom = bars2,
        height = publisher_cgsales_df["Other Sales (m)"],
        color = '#20639B',
        edgecolor = 'black')

plt.xticks(rotation = 85, fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Total Sales by Publisher by Country Grouping ", fontsize = 16, fontweight = "bold")
plt.ylabel("Total Sales(m)", fontsize = 13)
plt.legend(labels = labels, fontsize = "large")
#plt.savefig("TotalSalesByPublisherByCG.png")
plt.show()

# %% [markdown]
# ### This concludes the Exploratory Data Analysis of the Video Game Sales data

# %% [markdown]
# #### Note: This is what I have gathered from the data that was available on the VG Sales website so numbers may not be 100% accurate as the site doesn't have access to every bit of information regarding video game sales.
